# %% [markdown]
# # Extract claim_evidence pairs from training set

# %% [markdown]
# ## Construct index dict

# %%
import os
import json

wiki_file_path = "./new-wiki-pages-text/"
train_file_path = "./JSONFiles/" + "train.json"
dev_file_path = "./JSONFiles/" + "devset.json"

train_output_path = "./TrainSentence/" + "training.csv"
dev_output_path = "./TrainSentence/" + "dev.csv"

# create index for evidences
evi_index = {}
head_index = {}
for file in os.listdir(wiki_file_path):
    print("processing file: " + file)
    file_name = wiki_file_path + file
    with open(file=file_name) as f:
        lines = f.readlines()
        for i in range(len(lines)):
            words = lines[i].split(" ")
            head = words[0]

            try:
                evi = (words[0], int(words[1]))
                evi_index.update({
                evi: (file, i)
                })
            except ValueError as e:
                continue
                
            if head in head_index.keys():
                head_index[head].append(int(words[1]))
            else:
                head_index.update({
                    head: [int(words[1])]
                })
# Out:
# processing file: wiki-009.txt
# processing file: wiki-021.txt
# processing file: wiki-035.txt
# processing file: wiki-034.txt
# processing file: wiki-020.txt
# processing file: wiki-008.txt
# processing file: wiki-036.txt
# processing file: wiki-022.txt
# processing file: wiki-023.txt
# processing file: wiki-037.txt
# processing file: wiki-033.txt
# processing file: wiki-027.txt
# processing file: wiki-026.txt
# processing file: wiki-032.txt
# processing file: wiki-024.txt
# processing file: wiki-030.txt
# processing file: wiki-018.txt
# processing file: wiki-019.txt
# processing file: wiki-031.txt
# processing file: wiki-025.txt
# processing file: wiki-042.txt
# processing file: wiki-056.txt
# processing file: wiki-081.txt
# processing file: wiki-095.txt
# processing file: wiki-094.txt
# processing file: wiki-080.txt
# processing file: wiki-057.txt
# processing file: wiki-043.txt
# processing file: wiki-069.txt
# processing file: wiki-055.txt
# processing file: wiki-041.txt
# processing file: wiki-096.txt
# processing file: wiki-082.txt
# processing file: wiki-109.txt
# processing file: wiki-108.txt
# processing file: wiki-083.txt
# processing file: wiki-097.txt
# processing file: wiki-040.txt
# processing file: wiki-054.txt
# processing file: wiki-068.txt
# processing file: wiki-050.txt
# processing file: wiki-044.txt
# processing file: wiki-078.txt
# processing file: wiki-093.txt
# processing file: wiki-087.txt
# processing file: wiki-086.txt
# processing file: wiki-092.txt
# processing file: wiki-079.txt
# processing file: wiki-045.txt
# processing file: wiki-051.txt
# processing file: wiki-047.txt
# processing file: wiki-053.txt
# processing file: wiki-084.txt
# processing file: wiki-090.txt
# processing file: wiki-091.txt
# processing file: wiki-085.txt
# processing file: wiki-052.txt
# processing file: wiki-046.txt
# processing file: wiki-063.txt
# processing file: wiki-077.txt
# processing file: wiki-088.txt
# processing file: wiki-103.txt
# processing file: wiki-102.txt
# processing file: wiki-089.txt
# processing file: wiki-076.txt
# processing file: wiki-062.txt
# processing file: wiki-048.txt
# processing file: wiki-074.txt
# processing file: wiki-060.txt
# processing file: wiki-100.txt
# processing file: wiki-101.txt
# processing file: wiki-061.txt
# processing file: wiki-075.txt
# processing file: wiki-049.txt
# processing file: wiki-071.txt
# processing file: wiki-065.txt
# processing file: wiki-059.txt
# processing file: wiki-105.txt
# processing file: wiki-104.txt
# processing file: wiki-058.txt
# processing file: wiki-064.txt
# processing file: wiki-070.txt
# processing file: wiki-066.txt
# processing file: wiki-072.txt
# processing file: wiki-099.txt
# processing file: wiki-106.txt
# processing file: wiki-107.txt
# processing file: wiki-098.txt
# processing file: wiki-073.txt
# processing file: wiki-067.txt
# processing file: wiki-028.txt
# processing file: wiki-014.txt
# processing file: wiki-015.txt
# processing file: wiki-001.txt
# processing file: wiki-029.txt
# processing file: wiki-017.txt
# processing file: wiki-003.txt
# processing file: wiki-002.txt
# processing file: wiki-016.txt
# processing file: wiki-012.txt
# processing file: wiki-006.txt
# processing file: wiki-007.txt
# processing file: wiki-013.txt
# processing file: wiki-005.txt
# processing file: wiki-011.txt
# processing file: wiki-039.txt
# processing file: wiki-038.txt
# processing file: wiki-010.txt
# processing file: wiki-004.txt

# %%
# head_index.get("José_Ferrer")

# %% [markdown]
# ## Build training set according to file

# %%
import pandas as pd
import linecache
import random

use_file = 0    # 0 for training set , 1 for dev set

# read training data
if use_file == 0:
    with open(train_file_path, 'r') as f:
        train = json.load(f)
elif use_file == 1:
    with open(dev_file_path, 'r') as f:
        train = json.load(f)

def get_evi_text(evi) -> str:
    evidence = (evi[0], int(evi[1]))
    file_index_tuple = evi_index.get(evidence)
    file = wiki_file_path + file_index_tuple[0]
    line_num = file_index_tuple[1]
    evi_text = linecache.getline(file,line_num + 1)
    evi_text = evi_text[2: len(evi_text) + 1]
    words = evi_text.split(" ")[2: len(evi_text)]
    evi_text = " ".join(words)
    return evi_text
    

claim_list = []
evi_list = []
label_list = []


for key in train.keys():
    item = train.get(key)
    evidence_list = item['evidence']
    if len(evidence_list) == 0:
        continue
    claim = item['claim']
        
    head_set = set()
    for evi in evidence_list:
        head = evi[0]
        head_set.add(head)
        
    for head in head_set:
        sentence_numbers = head_index.get(head)
        if sentence_numbers is None:
            continue
        for number in sentence_numbers:
            query_combination = [head, number]
            claim_list.append(claim)
            evi_list.append(get_evi_text(query_combination))
            if query_combination in evidence_list:
                label_list.append(1)
            else:
                label_list.append(0)

result_dict = {
    "claim": claim_list,
    "evidence": evi_list,
    "label": label_list
}
result_df = pd.DataFrame(result_dict)

if use_file == 0:
    result_df.to_csv(train_output_path, index=False)
elif use_file == 1:
    result_df.to_csv(dev_output_path, index=False)

# %%
result_df
# Out:
#                                                      claim  \
# 0        Nikolaj Coster-Waldau worked with the Fox Broa...
# 1        Nikolaj Coster-Waldau worked with the Fox Broa...
# 2        Nikolaj Coster-Waldau worked with the Fox Broa...
# 3        Nikolaj Coster-Waldau worked with the Fox Broa...
# 4        Nikolaj Coster-Waldau worked with the Fox Broa...
# 5        Nikolaj Coster-Waldau worked with the Fox Broa...
# 6        Nikolaj Coster-Waldau worked with the Fox Broa...
# 7        Nikolaj Coster-Waldau worked with the Fox Broa...
# 8        Nikolaj Coster-Waldau worked with the Fox Broa...
# 9        Nikolaj Coster-Waldau worked with the Fox Broa...
# 10       Nikolaj Coster-Waldau worked with the Fox Broa...
# 11       Nikolaj Coster-Waldau worked with the Fox Broa...
# 12       Nikolaj Coster-Waldau worked with the Fox Broa...
# 13       Nikolaj Coster-Waldau worked with the Fox Broa...
# 14       Nikolaj Coster-Waldau worked with the Fox Broa...
# 15       Nikolaj Coster-Waldau worked with the Fox Broa...
# 16       Nikolaj Coster-Waldau worked with the Fox Broa...
# 17                      Roman Atwood is a content creator.
# 18                      Roman Atwood is a content creator.
# 19                      Roman Atwood is a content creator.
# 20                      Roman Atwood is a content creator.
# 21                      Roman Atwood is a content creator.
# 22                      Roman Atwood is a content creator.
# 23       History of art includes architecture, dance, s...
# 24       History of art includes architecture, dance, s...
# 25       History of art includes architecture, dance, s...
# 26       History of art includes architecture, dance, s...
# 27       History of art includes architecture, dance, s...
# 28       History of art includes architecture, dance, s...
# 29       History of art includes architecture, dance, s...
# ...                                                    ...
# 1613762            Her stars American actress Rooney Mara.
# 1613763            Her stars American actress Rooney Mara.
# 1613764            Her stars American actress Rooney Mara.
# 1613765            Her stars American actress Rooney Mara.
# 1613766            Her stars American actress Rooney Mara.
# 1613767            Her stars American actress Rooney Mara.
# 1613768            Her stars American actress Rooney Mara.
# 1613769            Her stars American actress Rooney Mara.
# 1613770            Her stars American actress Rooney Mara.
# 1613771            Her stars American actress Rooney Mara.
# 1613772            Her stars American actress Rooney Mara.
# 1613773            Her stars American actress Rooney Mara.
# 1613774            Her stars American actress Rooney Mara.
# 1613775                    J. R. R. Tolkien created Gimli.
# 1613776                    J. R. R. Tolkien created Gimli.
# 1613777                    J. R. R. Tolkien created Gimli.
# 1613778                    J. R. R. Tolkien created Gimli.
# 1613779                    J. R. R. Tolkien created Gimli.
# 1613780                 Susan Sarandon is an award winner.
# 1613781                 Susan Sarandon is an award winner.
# 1613782                 Susan Sarandon is an award winner.
# 1613783                 Susan Sarandon is an award winner.
# 1613784                 Susan Sarandon is an award winner.
# 1613785                 Susan Sarandon is an award winner.
# 1613786                 Susan Sarandon is an award winner.
# 1613787                 Susan Sarandon is an award winner.
# 1613788                 Susan Sarandon is an award winner.
# 1613789                 Susan Sarandon is an award winner.
# 1613790                 Susan Sarandon is an award winner.
# 1613791                 Susan Sarandon is an award winner.
#
#                                                   evidence  label
# 0        Nikolaj Coster-Waldau Nikolaj Coster-Waldau ; ...      0
# 1        Nikolaj Coster-Waldau He graduated from Danish...      0
# 2        Nikolaj Coster-Waldau Coster-Waldau 's breakth...      0
# 3        Nikolaj Coster-Waldau Since then he has appear...      0
# 4        Nikolaj Coster-Waldau In the United States , h...      0
# 5        Nikolaj Coster-Waldau He then played Detective...      1
# 6        Nikolaj Coster-Waldau He became widely known t...      0
# 7        Nikolaj Coster-Waldau In 2017 , he became one ...      0
# 8        Fox Broadcasting Company The Fox Broadcasting ...      1
# 9        Fox Broadcasting Company The network is headqu...      0
# 10       Fox Broadcasting Company It is the third large...      0
# 11       Fox Broadcasting Company Launched on October 9...      0
# 12       Fox Broadcasting Company It was the highest-ra...      0
# 13       Fox Broadcasting Company Fox and its affiliate...      0
# 14       Fox Broadcasting Company Most viewers in Canad...      0
# 15       Fox Broadcasting Company The network is named ...      0
# 16       Fox Broadcasting Company Fox is a member of th...      0
# 17       Roman Atwood Roman Bernard Atwood born May 28 ...      0
# 18       Roman Atwood He is best known for his vlogs , ...      1
# 19       Roman Atwood His vlogging channel , `` RomanAt...      0
# 20       Roman Atwood He also has another YouTube chann...      1
# 21       Roman Atwood His prank videos have gained over...      0
# 22       Roman Atwood Both of these channels are in the...      0
# 23       History of art The history of art is the histo...      0
# 24       History of art Over time visual art has been c...      0
# 25       History of art The subsequent expansion of the...      1
# 26       History of art In addition to the old forms of...      0
# 27       History of art The history of art is a multidi...      0
# 28       History of art The study of the history of art...      0
# 29       History of art However , as time has passed , ...      0
# ...                                                    ...    ...
# 1613762  Her film It was later given a wide release at ...      0
# 1613763  Her film Her received widespread critical accl...      0
# 1613764  Her film The film received numerous awards and...      0
# 1613765  Her film At the 86th Academy Awards , Her rece...      0
# 1613766  Her film Jonze also won awards for his screenp...      0
# 1613767  Rooney Mara Patricia Rooney Mara ; born April ...      1
# 1613768  Rooney Mara She made her screen debut in the s...      0
# 1613769  Rooney Mara In 2011 , Mara portrayed Lisbeth S...      0
# 1613770  Rooney Mara She received critical acclaim for ...      0
# 1613771  Rooney Mara In 2013 , she starred in the thril...      0
# 1613772  Rooney Mara The following year , she starred i...      0
# 1613773  Rooney Mara In 2015 , she garnered further cri...      0
# 1613774  Rooney Mara Mara is also known for her charity...      0
# 1613775  Gimli Middle-earth Gimli is a fictional charac...      1
# 1613776  Gimli Middle-earth A dwarf warrior , he is the...      1
# 1613777  Gimli Middle-earth Gimli is chosen to represen...      0
# 1613778  Gimli Middle-earth As such , he is one of the ...      0
# 1613779  Gimli Middle-earth In the course of the advent...      0
# 1613780  Susan Sarandon Susan Abigail Sarandon Tomalin ...      0
# 1613781  Susan Sarandon She is an Academy Award and BAF...      1
# 1613782  Susan Sarandon She was appointed a UNICEF Good...      1
# 1613783  Susan Sarandon Sarandon began her career in th...      0
# 1613784  Susan Sarandon In 1975 , she starred in the cu...      0
# 1613785  Susan Sarandon She was nominated for the Acade...      0
# 1613786  Susan Sarandon She has also won the BAFTA Awar...      1
# 1613787  Susan Sarandon Her other films include : Prett...      0
# 1613788  Susan Sarandon She made her Broadway debut in ...      0
# 1613789  Susan Sarandon She returned to Broadway in the...      0
# 1613790  Susan Sarandon On television , she is a five-t...      0
# 1613791  Susan Sarandon In 2017 , Sarandon portrayed Be...      0
#
# [1613792 rows x 3 columns]
