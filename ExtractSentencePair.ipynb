# %% [markdown]
# # Extract claim_evidence pairs from training set

# %% [markdown]
# ## Construct index dict

# %%
import os
import json

wiki_file_path = "./new-wiki-pages-text/"
train_file_path = "./JSONFiles/" + "train.json"
dev_file_path = "./JSONFiles/" + "devset.json"

train_output_path = "./TrainSentence/" + "training.csv"
dev_output_path = "./TrainSentence/" + "dev.csv"

# create index for evidences
evi_index = {}
head_index = {}
for file in os.listdir(wiki_file_path):
    print("processing file: " + file)
    file_name = wiki_file_path + file
    with open(file=file_name) as f:
        lines = f.readlines()
        for i in range(len(lines)):
            words = lines[i].split(" ")
            head = words[0]

            try:
                evi = (words[0], int(words[1]))
                evi_index.update({
                evi: (file, i)
                })
            except ValueError as e:
                continue
                
            if head in head_index.keys():
                head_index[head].append(int(words[1]))
            else:
                head_index.update({
                    head: [int(words[1])]
                })
# Out:
# processing file: wiki-007.txt
# processing file: wiki-081.txt
# processing file: wiki-008.txt
# processing file: wiki-107.txt
# processing file: wiki-078.txt
# processing file: wiki-050.txt
# processing file: wiki-098.txt
# processing file: wiki-055.txt
# processing file: wiki-043.txt
# processing file: wiki-002.txt
# processing file: wiki-044.txt
# processing file: wiki-082.txt
# processing file: wiki-072.txt
# processing file: wiki-070.txt
# processing file: wiki-011.txt
# processing file: wiki-053.txt
# processing file: wiki-010.txt
# processing file: wiki-022.txt
# processing file: wiki-030.txt
# processing file: wiki-091.txt
# processing file: wiki-077.txt
# processing file: wiki-009.txt
# processing file: wiki-031.txt
# processing file: wiki-065.txt
# processing file: wiki-102.txt
# processing file: wiki-006.txt
# processing file: wiki-052.txt
# processing file: wiki-092.txt
# processing file: wiki-075.txt
# processing file: wiki-012.txt
# processing file: wiki-059.txt
# processing file: wiki-064.txt
# processing file: wiki-023.txt
# processing file: wiki-068.txt
# processing file: wiki-073.txt
# processing file: wiki-004.txt
# processing file: wiki-109.txt
# processing file: wiki-054.txt
# processing file: wiki-103.txt
# processing file: wiki-066.txt
# processing file: wiki-020.txt
# processing file: wiki-100.txt
# processing file: wiki-034.txt
# processing file: wiki-104.txt
# processing file: wiki-069.txt
# processing file: wiki-036.txt
# processing file: wiki-090.txt
# processing file: wiki-038.txt
# processing file: wiki-079.txt
# processing file: wiki-032.txt
# processing file: wiki-096.txt
# processing file: wiki-046.txt
# processing file: wiki-028.txt
# processing file: wiki-080.txt
# processing file: wiki-099.txt
# processing file: wiki-033.txt
# processing file: wiki-017.txt
# processing file: wiki-019.txt
# processing file: wiki-089.txt
# processing file: wiki-105.txt
# processing file: wiki-024.txt
# processing file: wiki-060.txt
# processing file: wiki-085.txt
# processing file: wiki-106.txt
# processing file: wiki-025.txt
# processing file: wiki-058.txt
# processing file: wiki-003.txt
# processing file: wiki-108.txt
# processing file: wiki-005.txt
# processing file: wiki-042.txt
# processing file: wiki-087.txt
# processing file: wiki-048.txt
# processing file: wiki-040.txt
# processing file: wiki-071.txt
# processing file: wiki-095.txt
# processing file: wiki-021.txt
# processing file: wiki-057.txt
# processing file: wiki-101.txt
# processing file: wiki-097.txt
# processing file: wiki-041.txt
# processing file: wiki-029.txt
# processing file: wiki-083.txt
# processing file: wiki-026.txt
# processing file: wiki-062.txt
# processing file: wiki-049.txt
# processing file: wiki-056.txt
# processing file: wiki-045.txt
# processing file: wiki-047.txt
# processing file: wiki-094.txt
# processing file: wiki-063.txt
# processing file: wiki-074.txt
# processing file: wiki-018.txt
# processing file: wiki-051.txt
# processing file: wiki-067.txt
# processing file: wiki-016.txt
# processing file: wiki-001.txt
# processing file: wiki-013.txt
# processing file: wiki-037.txt
# processing file: wiki-086.txt
# processing file: wiki-084.txt
# processing file: wiki-035.txt
# processing file: wiki-015.txt
# processing file: wiki-093.txt
# processing file: wiki-039.txt
# processing file: wiki-014.txt
# processing file: wiki-088.txt
# processing file: wiki-061.txt
# processing file: wiki-076.txt
# processing file: wiki-027.txt

# %%
# head_index.get("José_Ferrer")

# %% [markdown]
# ## Build training set according to file

# %%
import pandas as pd
import linecache
import random

use_file = 0    # 0 for training set , 1 for dev set

# read training data
if use_file == 0:
    with open(train_file_path, 'r') as f:
        train = json.load(f)
elif use_file == 1:
    with open(dev_file_path, 'r') as f:
        train = json.load(f)

def get_evi_text(evi) -> str:
    evidence = (evi[0], int(evi[1]))
    file_index_tuple = evi_index.get(evidence)
    file = wiki_file_path + file_index_tuple[0]
    line_num = file_index_tuple[1]
    evi_text = linecache.getline(file,line_num + 1)
    evi_text = evi_text[2: len(evi_text) + 1]
    words = evi_text.split(" ")[2: len(evi_text)]
    evi_text = " ".join(words)
    return evi_text
    

claim_list = []
evi_list = []
claim_evi_list = []
label_list = []


for key in train.keys():
    item = train.get(key)
    evidence_list = item['evidence']
    if len(evidence_list) == 0:
        continue
    claim = item['claim']
        
    head_set = set()
    for evi in evidence_list:
        head = evi[0]
        head_set.add(head)
        
    for head in head_set:
        sentence_numbers = head_index.get(head)
        if sentence_numbers is None:
            continue
        for number in sentence_numbers:
            query_combination = [head, number]
            evidence_text = get_evi_text(query_combination)
            
            claim_list.append(claim)
            evi_list.append(evidence_text)
            claim_evi_list.append(claim + " ||| " + evidence_text)
            if query_combination in evidence_list:
                label_list.append(1)
            else:
                label_list.append(0)

result_dict = {
    "claim": claim_list,
    "evidence": evi_list,
    "claim_evi_pair": claim_evi_list,
    "label": label_list
}
result_df = pd.DataFrame(result_dict)

if use_file == 0:
    result_df.to_csv(train_output_path, index=False)
elif use_file == 1:
    result_df.to_csv(dev_output_path, index=False)

# %%
result_df
# Out:
#                                          claim  \
# 0        The Wizard of Oz is based on a novel.
# 1        The Wizard of Oz is based on a novel.
# 2        The Wizard of Oz is based on a novel.
# 3        The Wizard of Oz is based on a novel.
# 4        The Wizard of Oz is based on a novel.
# 5        The Wizard of Oz is based on a novel.
# 6        The Wizard of Oz is based on a novel.
# 7        The Wizard of Oz is based on a novel.
# 8        The Wizard of Oz is based on a novel.
# 9        The Wizard of Oz is based on a novel.
# 10       The Wizard of Oz is based on a novel.
# 11       The Wizard of Oz is based on a novel.
# 12       The Wizard of Oz is based on a novel.
# 13       The Wizard of Oz is based on a novel.
# 14       The Wizard of Oz is based on a novel.
# 15       The Wizard of Oz is based on a novel.
# 16       The Wizard of Oz is based on a novel.
# 17       The Wizard of Oz is based on a novel.
# 18                   Bruce Willis is an actor.
# 19                   Bruce Willis is an actor.
# 20                   Bruce Willis is an actor.
# 21                   Bruce Willis is an actor.
# 22                   Bruce Willis is an actor.
# 23                   Bruce Willis is an actor.
# 24                   Shia LaBeouf is an actor.
# 25                   Shia LaBeouf is an actor.
# 26                   Shia LaBeouf is an actor.
# 27                   Shia LaBeouf is an actor.
# 28                   Shia LaBeouf is an actor.
# 29                   Shia LaBeouf is an actor.
# ...                                        ...
# 1613762            Carice van Houten is Dutch.
# 1613763            Carice van Houten is Dutch.
# 1613764            Carice van Houten is Dutch.
# 1613765            Carice van Houten is Dutch.
# 1613766            Carice van Houten is Dutch.
# 1613767            Carice van Houten is Dutch.
# 1613768            Carice van Houten is Dutch.
# 1613769            Carice van Houten is Dutch.
# 1613770            Carice van Houten is Dutch.
# 1613771               Ringo Starr is a person.
# 1613772               Ringo Starr is a person.
# 1613773               Ringo Starr is a person.
# 1613774               Ringo Starr is a person.
# 1613775               Ringo Starr is a person.
# 1613776               Ringo Starr is a person.
# 1613777               Ringo Starr is a person.
# 1613778               Ringo Starr is a person.
# 1613779               Ringo Starr is a person.
# 1613780               Ringo Starr is a person.
# 1613781               Ringo Starr is a person.
# 1613782               Ringo Starr is a person.
# 1613783               Ringo Starr is a person.
# 1613784               Ringo Starr is a person.
# 1613785               Ringo Starr is a person.
# 1613786               Ringo Starr is a person.
# 1613787               Ringo Starr is a person.
# 1613788               Ringo Starr is a person.
# 1613789               Ringo Starr is a person.
# 1613790               Ringo Starr is a person.
# 1613791               Ringo Starr is a person.
#
#                                             claim_evi_pair  \
# 0        The Wizard of Oz is based on a novel. ||| The ...
# 1        The Wizard of Oz is based on a novel. ||| The ...
# 2        The Wizard of Oz is based on a novel. ||| The ...
# 3        The Wizard of Oz is based on a novel. ||| The ...
# 4        The Wizard of Oz is based on a novel. ||| The ...
# 5        The Wizard of Oz is based on a novel. ||| The ...
# 6        The Wizard of Oz is based on a novel. ||| The ...
# 7        The Wizard of Oz is based on a novel. ||| The ...
# 8        The Wizard of Oz is based on a novel. ||| The ...
# 9        The Wizard of Oz is based on a novel. ||| The ...
# 10       The Wizard of Oz is based on a novel. ||| The ...
# 11       The Wizard of Oz is based on a novel. ||| The ...
# 12       The Wizard of Oz is based on a novel. ||| The ...
# 13       The Wizard of Oz is based on a novel. ||| The ...
# 14       The Wizard of Oz is based on a novel. ||| The ...
# 15       The Wizard of Oz is based on a novel. ||| The ...
# 16       The Wizard of Oz is based on a novel. ||| The ...
# 17       The Wizard of Oz is based on a novel. ||| The ...
# 18       Bruce Willis is an actor. ||| Bruce Willis Wal...
# 19       Bruce Willis is an actor. ||| Bruce Willis His...
# 20       Bruce Willis is an actor. ||| Bruce Willis He ...
# 21       Bruce Willis is an actor. ||| Bruce Willis He ...
# 22       Bruce Willis is an actor. ||| Bruce Willis Wil...
# 23       Bruce Willis is an actor. ||| Bruce Willis Sin...
# 24       Shia LaBeouf is an actor. ||| Shia LaBeouf Shi...
# 25       Shia LaBeouf is an actor. ||| Shia LaBeouf He ...
# 26       Shia LaBeouf is an actor. ||| Shia LaBeouf He ...
# 27       Shia LaBeouf is an actor. ||| Shia LaBeouf In ...
# 28       Shia LaBeouf is an actor. ||| Shia LaBeouf In ...
# 29       Shia LaBeouf is an actor. ||| Shia LaBeouf The...
# ...                                                    ...
# 1613762  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613763  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613764  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613765  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613766  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613767  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613768  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613769  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613770  Carice van Houten is Dutch. ||| Carice van Hou...
# 1613771  Ringo Starr is a person. ||| Ringo Starr Richa...
# 1613772  Ringo Starr is a person. ||| Ringo Starr He oc...
# 1613773  Ringo Starr is a person. ||| Ringo Starr He al...
# 1613774  Ringo Starr is a person. ||| Ringo Starr Starr...
# 1613775  Ringo Starr is a person. ||| Ringo Starr In 19...
# 1613776  Ringo Starr is a person. ||| Ringo Starr Soon ...
# 1613777  Ringo Starr is a person. ||| Ringo Starr In 19...
# 1613778  Ringo Starr is a person. ||| Ringo Starr When ...
# 1613779  Ringo Starr is a person. ||| Ringo Starr After...
# 1613780  Ringo Starr is a person. ||| Ringo Starr Starr...
# 1613781  Ringo Starr is a person. ||| Ringo Starr After...
# 1613782  Ringo Starr is a person. ||| Ringo Starr In 19...
# 1613783  Ringo Starr is a person. ||| Ringo Starr He ac...
# 1613784  Ringo Starr is a person. ||| Ringo Starr He ha...
# 1613785  Ringo Starr is a person. ||| Ringo Starr He al...
# 1613786  Ringo Starr is a person. ||| Ringo Starr Since...
# 1613787  Ringo Starr is a person. ||| Ringo Starr Starr...
# 1613788  Ringo Starr is a person. ||| Ringo Starr Ringo...
# 1613789  Ringo Starr is a person. ||| Ringo Starr He wa...
# 1613790  Ringo Starr is a person. ||| Ringo Starr In 20...
# 1613791  Ringo Starr is a person. ||| Ringo Starr Starr...
#
#                                                   evidence  label
# 0        The Wizard of Oz 1939 film The Wizard of Oz is...      1
# 1        The Wizard of Oz 1939 film The film stars Judy...      0
# 2        The Wizard of Oz 1939 film The co-stars are Ra...      0
# 3        The Wizard of Oz 1939 film Notable for its use...      0
# 4        The Wizard of Oz 1939 film It was nominated fo...      0
# 5        The Wizard of Oz 1939 film It did win in two o...      0
# 6        The Wizard of Oz 1939 film However , the film ...      0
# 7        The Wizard of Oz 1939 film It was MGM 's most ...      0
# 8        The Wizard of Oz 1939 film The 1956 broadcast ...      0
# 9        The Wizard of Oz 1939 film The film was named ...      0
# 10       The Wizard of Oz 1939 film Designation on the ...      0
# 11       The Wizard of Oz 1939 film It is also one of t...      0
# 12       The Wizard of Oz 1939 film The Wizard of Oz is...      0
# 13       The Wizard of Oz 1939 film It is the source of...      0
# 14       The Wizard of Oz 1939 film It was directed pri...      0
# 15       The Wizard of Oz 1939 film Noel Langley , Flor...      0
# 16       The Wizard of Oz 1939 film The songs were writ...      0
# 17       The Wizard of Oz 1939 film The musical score a...      0
# 18       Bruce Willis Walter Bruce Willis born March 19...      1
# 19       Bruce Willis His career began on the Off-Broad...      0
# 20       Bruce Willis He is known for his role of John ...      1
# 21       Bruce Willis He has appeared in over 60 films ...      1
# 22       Bruce Willis Willis married actress Demi Moore...      0
# 23       Bruce Willis Since 2009 , he has been married ...      0
# 24       Shia LaBeouf Shia Saide LaBeouf _ born June 11...      1
# 25       Shia LaBeouf He became known among younger aud...      0
# 26       Shia LaBeouf He made his film debut in Holes 2...      0
# 27       Shia LaBeouf In 2004 , he made his directorial...      0
# 28       Shia LaBeouf In 2007 , LaBeouf starred in the ...      0
# 29       Shia LaBeouf The same year he was cast in Mich...      0
# ...                                                    ...    ...
# 1613762  Carice van Houten Born in Leiderdorp , a town ...      0
# 1613763  Carice van Houten Her younger sister Jelka is ...      0
# 1613764  Carice van Houten She was exposed to the perfo...      0
# 1613765  Carice van Houten Her first leading role as th...      0
# 1613766  Carice van Houten She gained widespread recogn...      0
# 1613767  Carice van Houten She was nominated for a Satu...      0
# 1613768  Carice van Houten Her other notable English-la...      0
# 1613769  Carice van Houten Since 2012 , Van Houten has ...      0
# 1613770  Carice van Houten After meeting Australian act...      0
# 1613771  Ringo Starr Richard Starkey , born 7 July 1940...      1
# 1613772  Ringo Starr He occasionally sang lead vocals ,...      0
# 1613773  Ringo Starr He also wrote the Beatles ' songs ...      0
# 1613774  Ringo Starr Starr was twice afflicted by life-...      0
# 1613775  Ringo Starr In 1955 , he entered the workforce...      0
# 1613776  Ringo Starr Soon afterwards , he became intere...      0
# 1613777  Ringo Starr In 1957 , he cofounded his first b...      0
# 1613778  Ringo Starr When the Beatles formed in 1960 , ...      0
# 1613779  Ringo Starr After achieving moderate success w...      0
# 1613780  Ringo Starr Starr played key roles in the Beat...      0
# 1613781  Ringo Starr After the band 's break-up in 1970...      0
# 1613782  Ringo Starr In 1972 , he released his most suc...      0
# 1613783  Ringo Starr He achieved commercial and critica...      0
# 1613784  Ringo Starr He has been featured in a number o...      0
# 1613785  Ringo Starr He also narrated the first two ser...      0
# 1613786  Ringo Starr Since 1989 , he has toured with tw...      0
# 1613787  Ringo Starr Starr 's creative contribution to ...      0
# 1613788  Ringo Starr Ringo 's popularity brought forth ...      0
# 1613789  Ringo Starr He was inducted into the Modern Dr...      0
# 1613790  Ringo Starr In 2011 , Rolling Stone readers na...      0
# 1613791  Ringo Starr Starr , who was previously inducte...      0
#
# [1613792 rows x 4 columns]
