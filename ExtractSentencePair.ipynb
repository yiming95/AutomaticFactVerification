# %% [markdown]
# # Extract claim_evidence pairs from training set

# %% [markdown]
# ## Construct index dict

# %%
import os
import json

wiki_file_path = "./new-wiki-pages-text/"
train_file_path = "./JSONFiles/" + "train.json"
dev_file_path = "./JSONFiles/" + "devset.json"

train_output_path = "./TrainSentence/" + "training.csv"
dev_output_path = "./TrainSentence/" + "dev.csv"

# create index for evidences
evi_index = {}
head_index = {}
for file in os.listdir(wiki_file_path):
    print("processing file: " + file)
    file_name = wiki_file_path + file
    with open(file=file_name) as f:
        lines = f.readlines()
        for i in range(len(lines)):
            words = lines[i].split(" ")
            head = words[0]

            try:
                evi = (words[0], int(words[1]))
                evi_index.update({
                evi: (file, i)
                })
            except ValueError as e:
                continue
                
            if head in head_index.keys():
                head_index[head].append(int(words[1]))
            else:
                head_index.update({
                    head: [int(words[1])]
                })
# Out:
# processing file: wiki-009.txt
# processing file: wiki-021.txt
# processing file: wiki-035.txt
# processing file: wiki-034.txt
# processing file: wiki-020.txt
# processing file: wiki-008.txt
# processing file: wiki-036.txt
# processing file: wiki-022.txt
# processing file: wiki-023.txt
# processing file: wiki-037.txt
# processing file: wiki-033.txt
# processing file: wiki-027.txt
# processing file: wiki-026.txt
# processing file: wiki-032.txt
# processing file: wiki-024.txt
# processing file: wiki-030.txt
# processing file: wiki-018.txt
# processing file: wiki-019.txt
# processing file: wiki-031.txt
# processing file: wiki-025.txt
# processing file: wiki-042.txt
# processing file: wiki-056.txt
# processing file: wiki-081.txt
# processing file: wiki-095.txt
# processing file: wiki-094.txt
# processing file: wiki-080.txt
# processing file: wiki-057.txt
# processing file: wiki-043.txt
# processing file: wiki-069.txt
# processing file: wiki-055.txt
# processing file: wiki-041.txt
# processing file: wiki-096.txt
# processing file: wiki-082.txt
# processing file: wiki-109.txt
# processing file: wiki-108.txt
# processing file: wiki-083.txt
# processing file: wiki-097.txt
# processing file: wiki-040.txt
# processing file: wiki-054.txt
# processing file: wiki-068.txt
# processing file: wiki-050.txt
# processing file: wiki-044.txt
# processing file: wiki-078.txt
# processing file: wiki-093.txt
# processing file: wiki-087.txt
# processing file: wiki-086.txt
# processing file: wiki-092.txt
# processing file: wiki-079.txt
# processing file: wiki-045.txt
# processing file: wiki-051.txt
# processing file: wiki-047.txt
# processing file: wiki-053.txt
# processing file: wiki-084.txt
# processing file: wiki-090.txt
# processing file: wiki-091.txt
# processing file: wiki-085.txt
# processing file: wiki-052.txt
# processing file: wiki-046.txt
# processing file: wiki-063.txt
# processing file: wiki-077.txt
# processing file: wiki-088.txt
# processing file: wiki-103.txt
# processing file: wiki-102.txt
# processing file: wiki-089.txt
# processing file: wiki-076.txt
# processing file: wiki-062.txt
# processing file: wiki-048.txt
# processing file: wiki-074.txt
# processing file: wiki-060.txt
# processing file: wiki-100.txt
# processing file: wiki-101.txt
# processing file: wiki-061.txt
# processing file: wiki-075.txt
# processing file: wiki-049.txt
# processing file: wiki-071.txt
# processing file: wiki-065.txt
# processing file: wiki-059.txt
# processing file: wiki-105.txt
# processing file: wiki-104.txt
# processing file: wiki-058.txt
# processing file: wiki-064.txt
# processing file: wiki-070.txt
# processing file: wiki-066.txt
# processing file: wiki-072.txt
# processing file: wiki-099.txt
# processing file: wiki-106.txt
# processing file: wiki-107.txt
# processing file: wiki-098.txt
# processing file: wiki-073.txt
# processing file: wiki-067.txt
# processing file: wiki-028.txt
# processing file: wiki-014.txt
# processing file: wiki-015.txt
# processing file: wiki-001.txt
# processing file: wiki-029.txt
# processing file: wiki-017.txt
# processing file: wiki-003.txt
# processing file: wiki-002.txt
# processing file: wiki-016.txt
# processing file: wiki-012.txt
# processing file: wiki-006.txt
# processing file: wiki-007.txt
# processing file: wiki-013.txt
# processing file: wiki-005.txt
# processing file: wiki-011.txt
# processing file: wiki-039.txt
# processing file: wiki-038.txt
# processing file: wiki-010.txt
# processing file: wiki-004.txt

# %%
# head_index.get("José_Ferrer")

# %% [markdown]
# ## Build training set according to file

# %%
import pandas as pd
import linecache
import numpy as np
import random
from sklearn.utils import shuffle

use_file = 0    # 0 for training set , 1 for dev set

# read training data
if use_file == 0:
    with open(train_file_path, 'r') as f:
        train = json.load(f)
elif use_file == 1:
    with open(dev_file_path, 'r') as f:
        train = json.load(f)

def get_evi_text(evi) -> str:
    evidence = (evi[0], int(evi[1]))
    file_index_tuple = evi_index.get(evidence)
    file = wiki_file_path + file_index_tuple[0]
    line_num = file_index_tuple[1]
    evi_text = linecache.getline(file,line_num + 1)
    evi_text = evi_text[2: len(evi_text) + 1]
    words = evi_text.split(" ")[2: len(evi_text)]
    evi_text = " ".join(words)
    return evi_text
    

claim_list = []
evi_list = []
claim_evi_list = []
label_list = []

np.random.seed(3)

for key in train.keys():
    item = train.get(key)
    evidence_list = item['evidence']
    if len(evidence_list) == 0:
        continue
    claim = item['claim']
        
    head_set = set()
    for evi in evidence_list:
        head = evi[0]
        head_set.add(head)
        
    for head in head_set:
        sentence_numbers = head_index.get(head)
        if sentence_numbers is None:
            continue
        for number in sentence_numbers:
            query_combination = [head, number]
            evidence_text = get_evi_text(query_combination)
            
            if query_combination in evidence_list:
                label_list.append(1)
            else:
                probability = np.random.rand()
                if probability > 0.2:
                    continue
                label_list.append(0)
                
            claim_list.append(claim)
            evi_list.append(evidence_text)
            claim_evi_list.append(claim + " ||| " + evidence_text)

result_dict = {
    "claim": claim_list,
    "evidence": evi_list,
    "claim_evi_pair": claim_evi_list,
    "label": label_list
}
result_df = pd.DataFrame(result_dict)
result_df = shuffle(result_df)

if use_file == 0:
    result_df.to_csv(train_output_path, index=False)
elif use_file == 1:
    result_df.to_csv(dev_output_path, index=False)

# %%
result_df
# Out:
#                                                     claim  \
# 0       Nikolaj Coster-Waldau worked with the Fox Broa...
# 1       Nikolaj Coster-Waldau worked with the Fox Broa...
# 2       Nikolaj Coster-Waldau worked with the Fox Broa...
# 3       Nikolaj Coster-Waldau worked with the Fox Broa...
# 4       Nikolaj Coster-Waldau worked with the Fox Broa...
# 5                      Roman Atwood is a content creator.
# 6                      Roman Atwood is a content creator.
# 7                      Roman Atwood is a content creator.
# 8       History of art includes architecture, dance, s...
# 9       History of art includes architecture, dance, s...
# 10                      Adrienne Bailon is an accountant.
# 11                      Adrienne Bailon is an accountant.
# 12      Homeland is an American television spy thrille...
# 13      Homeland is an American television spy thrille...
# 14      Homeland is an American television spy thrille...
# 15      The Boston Celtics play their home games at TD...
# 16      The Boston Celtics play their home games at TD...
# 17                  The Ten Commandments is an epic film.
# 18                  The Ten Commandments is an epic film.
# 19                  The Ten Commandments is an epic film.
# 20                  The Ten Commandments is an epic film.
# 21                  The Ten Commandments is an epic film.
# 22                  The Ten Commandments is an epic film.
# 23                  The Ten Commandments is an epic film.
# 24                  The Ten Commandments is an epic film.
# 25                  The Ten Commandments is an epic film.
# 26           Tetris has sold millions of physical copies.
# 27      Cyndi Lauper won the Best New Artist award at ...
# 28      Cyndi Lauper won the Best New Artist award at ...
# 29      Cyndi Lauper won the Best New Artist award at ...
# ...                                                   ...
# 484602              Sarah Michelle Gellar was in a movie.
# 484603              Sarah Michelle Gellar was in a movie.
# 484604              Sarah Michelle Gellar was in a movie.
# 484605              Sarah Michelle Gellar was in a movie.
# 484606              Sarah Michelle Gellar was in a movie.
# 484607              Sarah Michelle Gellar was in a movie.
# 484608              Sarah Michelle Gellar was in a movie.
# 484609              Sarah Michelle Gellar was in a movie.
# 484610  Led Zeppelin released an eponymous debut album...
# 484611  Led Zeppelin released an eponymous debut album...
# 484612  Led Zeppelin released an eponymous debut album...
# 484613  Led Zeppelin released an eponymous debut album...
# 484614  Led Zeppelin released an eponymous debut album...
# 484615  Led Zeppelin released an eponymous debut album...
# 484616                                 Taal was romantic.
# 484617                                 Taal was romantic.
# 484618                                 Taal was romantic.
# 484619            Her stars American actress Rooney Mara.
# 484620            Her stars American actress Rooney Mara.
# 484621            Her stars American actress Rooney Mara.
# 484622            Her stars American actress Rooney Mara.
# 484623            Her stars American actress Rooney Mara.
# 484624            Her stars American actress Rooney Mara.
# 484625            Her stars American actress Rooney Mara.
# 484626                    J. R. R. Tolkien created Gimli.
# 484627                    J. R. R. Tolkien created Gimli.
# 484628                 Susan Sarandon is an award winner.
# 484629                 Susan Sarandon is an award winner.
# 484630                 Susan Sarandon is an award winner.
# 484631                 Susan Sarandon is an award winner.
#
#                                                  evidence  \
# 0       Fox Broadcasting Company The Fox Broadcasting ...
# 1       Fox Broadcasting Company The network is named ...
# 2       Nikolaj Coster-Waldau Nikolaj Coster-Waldau ; ...
# 3       Nikolaj Coster-Waldau Coster-Waldau 's breakth...
# 4       Nikolaj Coster-Waldau He then played Detective...
# 5       Roman Atwood He is best known for his vlogs , ...
# 6       Roman Atwood His vlogging channel , `` RomanAt...
# 7       Roman Atwood He also has another YouTube chann...
# 8       History of art The subsequent expansion of the...
# 9       History of art The study of the history of art...
# 10      Adrienne Bailon Adrienne Eliza Houghton Bailon...
# 11      Adrienne Bailon Aside from her work in film , ...
# 12      Prisoners of War TV series Prisoners of War or...
# 13      Homeland TV series Homeland is an American spy...
# 14      Homeland TV series On December 9 , 2015 , the ...
# 15      Boston Celtics The Celtics play their home gam...
# 16      Boston Celtics After the end of the second `` ...
# 17      The Ten Commandments 1956 film The Ten Command...
# 18      The Ten Commandments 1956 film Charlton Heston...
# 19      The Ten Commandments 1956 film Yul Brynner won...
# 20      The Ten Commandments 1956 film It is also one ...
# 21      The Ten Commandments 1956 film According to Gu...
# 22      The Ten Commandments 1956 film In 1999 , the f...
# 23      The Ten Commandments 1956 film In June 2008 , ...
# 24      The Ten Commandments 1956 film The film was li...
# 25      The Ten Commandments 1956 film The last credit...
# 26      Tetris In January 2010 , it was announced that...
# 27      Cyndi Lauper Her debut solo album She 's So Un...
# 28      Cyndi Lauper This album included the number on...
# 29      Cyndi Lauper Since 1989 , Lauper has released ...
# ...                                                   ...
# 484602  Sarah Michelle Gellar She subsequently appeare...
# 484603  Sarah Michelle Gellar Her later film credits i...
# 484604  Sarah Michelle Gellar She headlined the short ...
# 484605  Sarah Michelle Gellar In October 2015 , Gellar...
# 484606  Scooby-Doo film Scooby-Doo also known as Scoob...
# 484607  Scooby-Doo film Based on the long-running Hann...
# 484608  Scooby-Doo film The plot revolves around Myste...
# 484609  Scooby-Doo film The Scooby-Doo Spooky Coaster ...
# 484610  Led Zeppelin album Led Zeppelin is the eponymo...
# 484611  Led Zeppelin album In 2003 , Led Zeppelin was ...
# 484612  Led Zeppelin Although the group was initially ...
# 484613  Led Zeppelin Page wrote most of Led Zeppelin '...
# 484614  Led Zeppelin With RIAA-certified sales of 111....
# 484615  Led Zeppelin They were inducted into the Rock ...
# 484616  Taal film Taal English : Rhythm is a 1999 Boll...
# 484617  Taal film Taal was screened retrospectively , ...
# 484618  Taal film The film stars Anil Kapoor , Akshaye...
# 484619  Rooney Mara Patricia Rooney Mara ; born April ...
# 484620  Rooney Mara She made her screen debut in the s...
# 484621  Her film Her is a 2013 American romantic scien...
# 484622  Her film It marks Jonze 's solo screenwriting ...
# 484623  Her film The film also stars Amy Adams , Roone...
# 484624  Her film Her premiered at the 2013 New York Fi...
# 484625  Her film It was later given a wide release at ...
# 484626  Gimli Middle-earth Gimli is a fictional charac...
# 484627  Gimli Middle-earth A dwarf warrior , he is the...
# 484628  Susan Sarandon She is an Academy Award and BAF...
# 484629  Susan Sarandon She was appointed a UNICEF Good...
# 484630  Susan Sarandon She has also won the BAFTA Awar...
# 484631  Susan Sarandon She made her Broadway debut in ...
#
#                                            claim_evi_pair  label
# 0       Nikolaj Coster-Waldau worked with the Fox Broa...      1
# 1       Nikolaj Coster-Waldau worked with the Fox Broa...      0
# 2       Nikolaj Coster-Waldau worked with the Fox Broa...      0
# 3       Nikolaj Coster-Waldau worked with the Fox Broa...      0
# 4       Nikolaj Coster-Waldau worked with the Fox Broa...      1
# 5       Roman Atwood is a content creator. ||| Roman A...      1
# 6       Roman Atwood is a content creator. ||| Roman A...      0
# 7       Roman Atwood is a content creator. ||| Roman A...      1
# 8       History of art includes architecture, dance, s...      1
# 9       History of art includes architecture, dance, s...      0
# 10      Adrienne Bailon is an accountant. ||| Adrienne...      1
# 11      Adrienne Bailon is an accountant. ||| Adrienne...      0
# 12      Homeland is an American television spy thrille...      1
# 13      Homeland is an American television spy thrille...      1
# 14      Homeland is an American television spy thrille...      0
# 15      The Boston Celtics play their home games at TD...      1
# 16      The Boston Celtics play their home games at TD...      0
# 17      The Ten Commandments is an epic film. ||| The ...      1
# 18      The Ten Commandments is an epic film. ||| The ...      0
# 19      The Ten Commandments is an epic film. ||| The ...      0
# 20      The Ten Commandments is an epic film. ||| The ...      0
# 21      The Ten Commandments is an epic film. ||| The ...      0
# 22      The Ten Commandments is an epic film. ||| The ...      0
# 23      The Ten Commandments is an epic film. ||| The ...      0
# 24      The Ten Commandments is an epic film. ||| The ...      1
# 25      The Ten Commandments is an epic film. ||| The ...      0
# 26      Tetris has sold millions of physical copies. |...      1
# 27      Cyndi Lauper won the Best New Artist award at ...      1
# 28      Cyndi Lauper won the Best New Artist award at ...      0
# 29      Cyndi Lauper won the Best New Artist award at ...      0
# ...                                                   ...    ...
# 484602  Sarah Michelle Gellar was in a movie. ||| Sara...      1
# 484603  Sarah Michelle Gellar was in a movie. ||| Sara...      0
# 484604  Sarah Michelle Gellar was in a movie. ||| Sara...      0
# 484605  Sarah Michelle Gellar was in a movie. ||| Sara...      0
# 484606  Sarah Michelle Gellar was in a movie. ||| Scoo...      1
# 484607  Sarah Michelle Gellar was in a movie. ||| Scoo...      0
# 484608  Sarah Michelle Gellar was in a movie. ||| Scoo...      0
# 484609  Sarah Michelle Gellar was in a movie. ||| Scoo...      0
# 484610  Led Zeppelin released an eponymous debut album...      1
# 484611  Led Zeppelin released an eponymous debut album...      0
# 484612  Led Zeppelin released an eponymous debut album...      1
# 484613  Led Zeppelin released an eponymous debut album...      0
# 484614  Led Zeppelin released an eponymous debut album...      0
# 484615  Led Zeppelin released an eponymous debut album...      0
# 484616  Taal was romantic. ||| Taal film Taal English ...      1
# 484617  Taal was romantic. ||| Taal film Taal was scre...      0
# 484618  Taal was romantic. ||| Taal film The film star...      0
# 484619  Her stars American actress Rooney Mara. ||| Ro...      1
# 484620  Her stars American actress Rooney Mara. ||| Ro...      0
# 484621  Her stars American actress Rooney Mara. ||| He...      0
# 484622  Her stars American actress Rooney Mara. ||| He...      0
# 484623  Her stars American actress Rooney Mara. ||| He...      1
# 484624  Her stars American actress Rooney Mara. ||| He...      0
# 484625  Her stars American actress Rooney Mara. ||| He...      0
# 484626  J. R. R. Tolkien created Gimli. ||| Gimli Midd...      1
# 484627  J. R. R. Tolkien created Gimli. ||| Gimli Midd...      1
# 484628  Susan Sarandon is an award winner. ||| Susan S...      1
# 484629  Susan Sarandon is an award winner. ||| Susan S...      1
# 484630  Susan Sarandon is an award winner. ||| Susan S...      1
# 484631  Susan Sarandon is an award winner. ||| Susan S...      0
#
# [484632 rows x 4 columns]

# %%
result_df['label'].describe()
# Out:
# count    484632.000000
# mean          0.417979
# std           0.493227
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: label, dtype: float64
